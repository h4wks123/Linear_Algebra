# %% [markdown]
# $\text{Ivanne Dave L. Bayer}$

# %% [markdown]
# # <font color = red> Assignment 2 </font>
# ---
# **INSTRUCTION**
# - Use latex programming to show your manual solutions.
# - If the problem involves determining the row echelon or reduced row echelon, show both the manual and the pythonic solutions.
# - Solutions must be saved as a jupyter notebook.
# - Push your solutions to your forked github repo.
# - Note that there is some **possibility** that some ,or all, of your exam questions will be taken from these assignment.
# - The technique here is to first solve manually before writing in Latex.
# ---
# 1. Provide reasons why each of the following equations is, or is not, a linear equation.
# - $\cos{\theta}x+4y+z = \sqrt{3}$
#     - The equation above is not representative of a linear equation as the presence of the cosine function violates the criteria which in turn introduces nonlinearity. A linear equation has the prerequisites of not multiplying or dividing variables with each other and the term $\cos{\theta}x$ includes the product of both the $\cos{\theta}$ and x making it nonlinear.<br><br>
#
# - $cos{x}4y+z = \sqrt{3}$
#     - The equation shown above is a nonlinear equation because there are two issues that violates the criteria of linear equations which includes the presence of $\cos{x}$ as the variable must appear to the first power. Moreover, the multiplication of variables being represented in 4y also violates the criteria of linear equations.<br><br>
#
# - $x^{-1}+7y+z = \sin{(\frac{\pi}{2})}$
#     - The equation being represented above is a nonlinear equation as it violates the criteria of linear equations. In this equation, the term $x^{-1}$ represents the reciprocal of x, which violates the condition of having only variables raised to the first power. Moreover, the presence of $\sin{(\frac{\pi}{2})}$ introduces nonlinearity as it is a trigonometric function.<br><br>
# - $x^1+y^1+z^1=0$
#     - The equation shown above meets the criteria of a linear equation as it is characterized with the necessary prerequisites. The variables are raised only to the first power, which automatically satisfies this condition. Moreover, the variables are combined together with a coefficient of 1. In addition, the right side of the linear equation is a constant value being represented as 0.<br>

# %% [markdown]
# ---
# 2. Find the solutions to the linear equations:
# - $2x_1+3x_2 =5$
#
# - $4x_1+3x_2+2x_3=1$
#
# - $3x-6y=0$

# %% [markdown]
# ---
# 3. Solve the following systems of linear equations:
# - $L1: x - y = 0, \ L2: 2x + y = 3$
#     - *Forward Elimination:*
#         - $-2(x - y = 0)$
#         - $-2x + 2y = 0$
#     - *Add L1 and L2:*
#         - $\frac{3y}{3} = \frac{3}{3}$
#         - $y = 1$
#     - *Backward Substitution:*
#         - $x - 1 = 0$
#         - $x = 1$
#     - *Result:*
#         - $x = 1, \ y = 1$

# %%
import numpy as np

print("L1: x - y = 0, L2: 2x + y = 3")

u = np.array([1, -1, 0], dtype=float) 
v = np.array([2, 1, 3], dtype=float)

print("Forward Substitution: ")
u *= -2
u += v
u /= 3
print("y =", u[2])
print("Backward Substitution: ")
#idk if need sha e python tbh#
# Out:
# L1: x - y = 0, L2: 2x + y = 3
# Forward Substitution:
# y = 1.0
# Backward Substitution:

# %% [markdown]
# - $L1: x + 5y = -1, \ L2: -x + y = -5, \ L3: 2x + 4y = 4$ <br><br>
#     - *Forward Elimination:* <br><br>
# $
# \begin{pmatrix}
#     1 & 5 &\bigm| & -1 \\
#     -1 & 1 &\bigm| & -5 \\
#     2 & 4 &\bigm| & 4 \\
# \end{pmatrix}
# \xrightarrow[\text{R}_{3} - 2\text{R}_{1}]{\text{R}_{2} + \text{R}_{1}}
# \begin{pmatrix}
#     1 & 5 &\bigm| & -1 \\
#     0 & 6 &\bigm| & -6 \\
#     0 & -6 &\bigm| & 6 \\
# \end{pmatrix}
# \xrightarrow[\text{R}_{3}(\frac{1}{6})]{\text{R}_{2}(\frac{1}{6})}
# \begin{pmatrix}
#     1 & 5 &\bigm| & -1 \\
#     0 & 1 &\bigm| & -1 \\
#     0 & -1 &\bigm| & 1 \\
# \end{pmatrix}
# \xrightarrow[\text{R}_{3} + \text{R}_{2}]{}
# \begin{pmatrix}
#     1 & 5 &\bigm| & -1 \\
#     0 & 1 &\bigm| & -1 \\
#     0 & 0 &\bigm| & 0 \\
# \end{pmatrix}
# % \xrightarrow[\text{R}_{1} - 5\text{R}_{2}]{}
# % \begin{pmatrix}
# %     1 & 0 &\bigm| & 4 \\
# %     0 & 1 &\bigm| & -1 \\
# %     0 & 0 &\bigm| & 0 \\
# % \end{pmatrix}
# $
# <br><br>
#         - y = -1
# <br>
#     - *Backward Substitution:* <br>
#         - x + 5(-1) = -1
#         - x + -5 = -1
#         - x = 5 + (-1)
#         - x = 4
#     - *Result:*
#         - $x = 4, \ y = -1$

# %% [markdown]
# - $L1: 2x_1 + 3x_2 - x_3 = -1, \ L2: x_1 + x_3 = 0, \ L3: -x_1 + 2x_2 - 2x_3  = 0$ <br><br>
#     - *Forward Elimination:* <br><br>
# $
# \begin{pmatrix}
#     1 & 5 &\bigm| & -1 \\
#     -1 & 1 &\bigm| & -5 \\
#     2 & 4 &\bigm| & 4 \\
# \end{pmatrix}
# ---

# %% [markdown]
# 4. Provide reasons why the given matrices are either a row echelon, a reduced row echelon, or niether both.<br>
#
# a. <br>
# \begin{pmatrix}
#    1 & 0 & 1 \\
#    0 & 0 & 3 \\
#    0 & 1 & 0 \\
# \end{pmatrix}
#
#    - The matrix is not a row echelon since the leading entries of the second row being represented as zero is greater than the third row.
#    - The matrix is also not a reduced row echelon since it needs to satisfy the condition of a row echelon for it to be reduced.
#
# b. <br>
# \begin{pmatrix}
#    7 & 0 & 1 & 0 \\
#    0 & 1 & -1 & 4 \\
#    0 & 0 & 0 & 0 \\
# \end{pmatrix}
#
#    - The matrix meets the criteria of a row echelon as the third row has the most number of leading entries and both R1 and R2 are organized based on their leading entries.
#    - The matrix however is not a reduced row echelon as its leading entry in R1 is not one
#
# c. <br>
# \begin{pmatrix}
#    0 & 1 & 3 & 0 \\
#    0 & 0 & 0 & 1 \\
# \end{pmatrix}
#
#    - The matrix is in its reduced row echelon because the leading entries are zeroes and R2 has more leading entries compared to R1.
#
# d. <br>
# \begin{pmatrix}
#    0 & 0 & 0 \\
#    0 & 0 & 0 \\
#    0 & 0 & 0 \\
# \end{pmatrix}
#
#    - The matrix is neither a row echelon form or a reduced row echelon form since there are no nonzero elements, making the matrix null.
# e. <br>
# \begin{pmatrix}
#    1 & 0 & 3 & -4 & 0 \\
#    0 & 0 & 0 & 0 & 0 \\
#    0 & 1 & 5 & 0 & 1 \\
# \end{pmatrix}
#
#    - The matrix is not a row echelon form since R2 has the most leading entries represented as zero which should be placed at R3.
#    - The matrix cannot be a reduced row echelon form if it does not satisfy the row echelon form condition.
#
# f. <br>
# \begin{pmatrix}
#    0 & 0 & 1 \\
#    0 & 1 & 0 \\
#    1 & 0 & 0 \\
# \end{pmatrix}
#
#    - The matrix is in its reduced row echelon form since its leading entries are 1 and they are sorrounded by zeroes forming a triangle.
#
# g. <br>
# \begin{pmatrix}
#    1 & 2 & 3 \\
#    1 & 0 & 0 \\
#    0 & 1 & 1 \\
#    0 & 0 & 1 \\
# \end{pmatrix}
#
#    - The matrix is in its row echelon form as the leading entries with zeros in R3 is less than R4 and both the leading entries of R1 and R2 are represented as non zeroes.
#
# h. <br>
# \begin{pmatrix}
#    2 & 1 & 3 & 5 \\
#    0 & 0 & 1 & -1 \\
#    0 & 0 & 0 & 3 \\
#    0 & 0 & 0 & 0 \\
# \end{pmatrix}
#
#    - The matrix is in its row echelon form as the leading entries of R2 is less than R3 and R3 is less than R4.
#    - The matrix cannot be considered as reduced row echelon form as the leading entry of R1 is neither one or zero.

# %% [markdown]
# ---
# 5. Solve the following systems of linear equations<br>
# a.<br>
# \begin{equation}
# x_1+2x_2-3x_3=9 \\
# 2x_1-x_2-x_3=0 \\
# 4x_1-x_2+x_3=4 \\
# \end{equation}
# <br>
# <br>
# b. <br>
# \begin{equation}
# x+2y= -1 \\
# 2x+y+z = 1 \\
# -x+y-z = -1
# \end{equation}
# c. <br>
# \begin{equation}
# x_1-3x_2-2x_3=0 \\
# -x_1+2x_2+x_3=0 \\
# 2x_1+4x_2+6x_3=0 \\
# \end{equation}
# <br>
# d. <br>
# \begin{equation}
# w+x+2y+z=1 \\
# w-x-y+z=0 \\
# x+y=1 \\
# w+x+z=2
# \end{equation}
# <br>

# %% [markdown]
# 6. Determine if the vectors are linear combinations<br>
# a. <br>
#  \begin{equation}
#     \textbf{v} = \begin{bmatrix} 1 \\ 2 \end{bmatrix} \
#     \textbf{u}_2 = \begin{bmatrix} -1 \\ 3 \end{bmatrix}\
#     \textbf{u}_3 = \begin{bmatrix} 2 \\ -6 \end{bmatrix}\\
# \end{equation}
# <br>
# \begin{pmatrix}
#    1\\
#    1 \\
# \end{pmatrix}
# <br>
# b. <br>
#  \begin{equation}
#     \textbf{v} = \begin{bmatrix} 1 \\ 2 \\ 3 \end{bmatrix} \
#     \textbf{u}_2 = \begin{bmatrix} 1 \\ 1 \\ 0 \end{bmatrix}\
#     \textbf{u}_3 = \begin{bmatrix} 0 \\ 1 \\ 1 \end{bmatrix}\\
# \end{equation}
# <br><br>
# c. <br>
#  \begin{equation}
#     \textbf{v} = \begin{bmatrix} 3 \\ 1 \\ -2 \end{bmatrix} \
#     \textbf{u}_2 = \begin{bmatrix} 1 \\ 1 \\ 0 \end{bmatrix}\
#     \textbf{u}_3 = \begin{bmatrix} 0 \\ 1 \\ 1 \end{bmatrix}\\
# \end{equation}
# <br><br>
# ---
